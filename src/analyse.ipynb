 365, 336, 332, 429, 369, 336, 336, 407, 364, 410, 345, 384, 365, 336, 379, 412, 358, 407, 336, 332, 399, 379, 399, 369, 402, 365, 369, 336, 336, 397, 384, 404, 416, 348, 336, 369, 372, 557, 369, 403, 367, 398, 332, 495, 360, 425, 360, 435, 399, 379, 336, 379, 399, 387, 399, 383, 336, 348, 403, 332, 365, 399, 388, 375, 336, 388, 336, 415, 332, 399, 365, 379, 399, 336, 397, 336, 348, 379, 352, 369, 485, 336, 390, 367, 332, 336, 416, 377, 379, 395, 336, 375, 348, 380, 521, 336, 369, 352, 332, 345, 364, 409, 411, 332, 365, 348, 388, 399, 399, 332, 399, 348, 388, 399, 367, 332, 393, 332, 384, 385, 348, 381, 374, 379, 336, 336, 352]

# %%
# imbalances1 = np.linspace(0, 0.15, 100)
    # imbalances2 = np.linspace(0.15, 0.4, 50)
    # # nb_trials = [2**i for i in range(1, 6)]
    #imbalances3 = np.arange(0.01, 0.1, 0.01)
    #fig, axs = plt.subplots(3, 3)
    #fig.suptitle('imbalance variation from 0 to 0.15')
    #fig.suptitle('9 cuts of paris, imbalance = 0.01')
    json_path = "./data/Paris.json"
    grahml_path = "./data/Paris.graphml"
    print(f"importing graphs...")
    G_kp = Graph(json=json_path)
    G_nx = ox.load_graphml(grahml_path)
    results = []
    for i in range(1000):
        print(f"operating cut {i}")
        G_kp.kaffpa_cut(2, 0.01, 0, rd.randint(0,1044642763), 2)
        results.append(G_kp._edgecut)
        #print(f"preparing the results...")
        #_, _ = G_kp.display_city_cut(G_nx, show=False, ax=axs[i//3, i%3], figsize=(3, 3))
    print(results)
   # plt.savefig(fname="./data/images/imbalances_paris_0,01-0,1.svg")
    #plt.savefig(fname="./data/images/imbalances_paris_0,01-0,1.png", dpi=1024)
    # G_kp.display_last_cut_results()
    # _, ax = plt.subplots()
    # ax.plot(imbalances, results)
    # plt.show()

# %%
# C = {}
    # collision = []
    # for i in range(10000):
    #     seed = rd.randint(0,1044642763)
    #     while seed in collision:
    #         print("collision")
    #         seed = rd.randint(0,1044642763)
    #     print(f"operating cut {i}")
    #     G_kp.kaffpa_cut(2, 0.01, 0, seed, 2)
    #     C[str(i)] = (G_kp.get_last_results)
    #     #print(f"preparing the results...")
    #     #_, _ = G_kp.display_city_cut(G_nx, show=False, ax=axs[i//3, i%3], figsize=(3, 3))
    # with open(r"./data/10000_cuts_Paris.json", "w") as write_file:
    #     json.dump(C, write_file)

# %% [markdown]
# Pour 1000 run sur Paris avec un desequilibre de 0.01 on obtient les stats suivantes:
#
# The most cut edge ((658, 18935)) has been cut 517 times
#
# The less cut edge has been cut 1 times
#
# We have a mean of 12.185642432556012
#
# We have an std of 29.424681846549113
#
# With 1000 cuts we have cut 4374 different edges over 46761
